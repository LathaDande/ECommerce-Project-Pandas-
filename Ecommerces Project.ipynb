# %%
import numpy as np
import pandas as pd
df=pd.read_csv("C:\\Users\\dande\\OneDrive\\Desktop\\Pandas\\E Commerece Project\\EcomPur.csv")
pd.set_option("display.max_columns",None)
print(df)
# Out:
#                                                 Address    Lot AM or PM  \
# 0     16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                      Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4     23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# ...                                                 ...    ...      ...
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# ...

# %%
df.head(10)
# Out:
#                                              Address    Lot AM or PM  \
# 0  16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1  9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                   Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3              7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4  23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# 5  7502 Powell Mission Apt. 768\nTravisland, VA 3...  21 XT       PM
# 6     93971 Conway Causeway\nAndersonburgh, AZ 75107  96 Xt       AM
# 7  260 Rachel Plains Suite 366\nCastroberg, WV 24...  96 pG       PM
# 8            2129 Dylan Burg\nNew Michelle, ME 28650  45 JN       PM
# 9    3795 Dawson Extensions\nLake Tinafort, ID 88739  15 Ug       AM
#
#                                         Browser Info  \
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# 1  Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
# ...

# %%
df.tail(10)
# Out:
#                                                 Address    Lot AM or PM  \
# 9990  75731 Molly Springs\nWest Danielle, VT 96934-5102  93 ty       PM
# 9991              PSC 8165, Box 8498\nAPO AP 60327-0346  50 dA       AM
# 9992  885 Allen Mountains Apt. 230\nWallhaven, LA 16995  40 vH       PM
# 9993  7555 Larson Locks Suite 229\nEllisburgh, MA 34...  72 jg       PM
# 9994       6276 Rojas Hollow\nLake Louis, WY 56410-7837  93 Ex       PM
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# 9990  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_7_4;...
# 9991  Mozilla/5.0 (compatible; MSIE 8.0; Windows NT ...
# ...

# %%
# 3. Check Datatype of Each Column
df.dtypes
# Out:
# Address              object
# Lot                  object
# AM or PM             object
# Browser Info         object
# Company              object
# Credit Card           int64
# CC Exp Date          object
# CC Security Code      int64
# CC Provider          object
# Email                object
# Job                  object
# IP Address           object
# Language             object
# Purchase Price      float64
# dtype: object

# %%
# 3. Check Datatype of Each Column
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Address           10000 non-null  object
#  1   Lot               10000 non-null  object
#  2   AM or PM          10000 non-null  object
#  3   Browser Info      10000 non-null  object
#  4   Company           10000 non-null  object
#  5   Credit Card       10000 non-null  int64
#  6   CC Exp Date       10000 non-null  object
#  7   CC Security Code  10000 non-null  int64
#  8   CC Provider       10000 non-null  object
#  9   Email             10000 non-null  object
#  10  Job               10000 non-null  object
#  11  IP Address        10000 non-null  object
#  12  Language          10000 non-null  object
#  13  Purchase Price    10000 non-null  float64
# dtypes: float64(1), int64(2), object(11)
# memory usage: 1.1+ MB

# %%
# 4. Check null values in the dataset
df.isnull().sum()
# Out:
# Address             0
# Lot                 0
# AM or PM            0
# Browser Info        0
# Company             0
# Credit Card         0
# CC Exp Date         0
# CC Security Code    0
# CC Provider         0
# Email               0
# Job                 0
# IP Address          0
# Language            0
# Purchase Price      0
# dtype: int64

# %%
# 5. How many rows and columns are there in our Dataset? 
df.shape
print("No.of rows in Data Frame:",df.shape[0])
print("No.of columns in Data Frame:",df.shape[1])
# Out:
# No.of rows in Data Frame: 10000
# No.of columns in Data Frame: 14

# %%
# 6. Highest and Lowest Purchase Prices.
print("Highest Purchase Prices:",df["Purchase Price"].max())
print("Lowest Purchase Prices:",df["Purchase Price"].min())
# Out:
# Highest Purchase Prices: 99.99
# Lowest Purchase Prices: 0.0

# %%
# 7. Average Purchase Price
df["Purchase Price"].mean()
# Out:
# 50.347302

# %%
# 8. How many people have French 'fr' as their Language?
df.columns
# Out:
# Index(['Address', 'Lot', 'AM or PM', 'Browser Info', 'Company', 'Credit Card',
#        'CC Exp Date', 'CC Security Code', 'CC Provider', 'Email', 'Job',
#        'IP Address', 'Language', 'Purchase Price'],
#       dtype='object')

# %%
df["Language"]
# Out:
# 0       el
# 1       fr
# 2       de
# 3       es
# 4       es
#         ..
# 9995    it
# 9996    pt
# 9997    el
# 9998    es
# 9999    el
# Name: Language, Length: 10000, dtype: object

# %%
df[df["Language"]=="fr"]
# Out:
#                                                 Address    Lot AM or PM  \
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 19                  125 Hall Summit\nBoothton, IL 41721  99 CU       PM
# 53                PSC 9431, Box 7059\nAPO AA 29285-1363  14 qD       AM
# 76    49206 Campbell Port\nNorth Cliffordshire, HI 3...  71 iu       PM
# 82    493 Smith Valleys Suite 004\nNew Madelineville...  35 ls       PM
# ...                                                 ...    ...      ...
# 9941           43757 Brown Lodge\nValerieberg, PR 88518  68 DG       AM
# 9947      32827 Carl Inlet\nSouth Nicole, NY 38081-6636  40 Dp       PM
# 9951                518 Brown Dam\nGarciaside, IN 33057  71 wq       AM
# 9977  02182 Keith Expressway\nEast Shannon, CT 20578...  34 RL       AM
# 9980           6061 Dave Lights\nPhillipsview, UT 40500  25 Mv       AM
#
#                                            Browser Info  \
# ...

# %%
# 8. How many people have French 'fr' as their Language?
print(f"{df[df["Language"]=="fr"].shape[0]} people have French 'fr' as their Language")
# Out:
# 1097 people have French 'fr' as their Language

# %%
# 9. Job Title Contains Engineer
df[df['Job'].str.contains("Engineer",case=False)]['Job']
# Out:
# 1                         Drilling engineer
# 3                         Drilling engineer
# 50                      Mechanical engineer
# 55      Engineer, broadcasting (operations)
# 60                   Engineer, agricultural
#                        ...
# 9948                    Structural engineer
# 9952                       Engineer, energy
# 9970                    Electrical engineer
# 9977                    Biomedical engineer
# 9996                        Energy engineer
# Name: Job, Length: 984, dtype: object

# %%
for val in df[df['Job'].str.contains("Engineer",case=False)]['Job']:
    print(val)
# Out:
# Drilling engineer
# Drilling engineer
# Mechanical engineer
# Engineer, broadcasting (operations)
# Engineer, agricultural
# Engineer, civil (consulting)
# Engineer, materials
# Engineer, land
# Engineer, water
# Technical sales engineer
# Engineer, aeronautical
# Engineering geologist
# Engineer, chemical
# Engineer, building services
# Energy engineer
# Water engineer
# Software engineer
# Engineer, civil (consulting)
# Engineer, civil (contracting)
# Structural engineer
# Mining engineer
# Engineer, energy
# Manufacturing systems engineer
# Control and instrumentation engineer
# Consulting civil engineer
# Engineer, structural
# Site engineer
# Engineer, building services
# Mining engineer
# Engineer, maintenance (IT)
# Consulting civil engineer
# Petroleum engineer
# Engineer, maintenance
# Communications engineer
# Energy engineer
# Civil engineer, consulting
# Engineer, production
# Mining engineer
# Engineer, energy
# Engineer, communications
# Engineer, drilling
# ...

# %%
# 10. Find The Email of the person with the following IP Address: 132.207.160.22
df.columns
# Out:
# Index(['Address', 'Lot', 'AM or PM', 'Browser Info', 'Company', 'Credit Card',
#        'CC Exp Date', 'CC Security Code', 'CC Provider', 'Email', 'Job',
#        'IP Address', 'Language', 'Purchase Price'],
#       dtype='object')

# %%
df['IP Address']
# Out:
# 0       149.146.147.205
# 1          15.160.41.51
# 2        132.207.160.22
# 3          30.250.74.19
# 4          24.140.33.94
#              ...
# 9995      29.73.197.114
# 9996     121.133.168.51
# 9997      156.210.0.254
# 9998       55.78.26.143
# 9999    176.119.198.199
# Name: IP Address, Length: 10000, dtype: object

# %%
df[df['IP Address']=="132.207.160.22"]
# Out:
#                             Address    Lot AM or PM  \
# 2  Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
#
#                                         Browser Info  \
# 2  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
#
#                       Company   Credit Card CC Exp Date  CC Security Code  \
# 2  Simpson, Williams and Pham  675957666125       08/19               699
#
#     CC Provider                           Email                       Job  \
# 2  JCB 16 digit  amymiller@morales-harrison.com  Customer service manager
#
#        IP Address Language  Purchase Price
# 2  132.207.160.22       de            0.95

# %%
df.loc[df['IP Address']=="132.207.160.22"][['Email']]
# Out:
#                             Email
# 2  amymiller@morales-harrison.com

# %%
df.loc[df['IP Address']=="132.207.160.22"][['Email']].to_string(index=False)
# Out:
# '                         Email\namymiller@morales-harrison.com'

# %%
# 11. How many People have Mastercard as their Credit Card Provider and made a purchase above 50?
df[(df['CC Provider']=="Mastercard") & (df['Purchase Price']>50.00)]
# Out:
#                                                 Address    Lot AM or PM  \
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 18    461 Christopher Square\nWest Michaelchester, C...  17 SB       PM
# 31                     USNS Alvarado\nFPO AA 27052-1231  26 Lh       PM
# 35    93392 Webb Gardens Apt. 220\nLaurabury, AR 999...  37 om       AM
# 90          431 Bowen Lights\nFergusonborough, MH 01362  31 tG       AM
# ...                                                 ...    ...      ...
# 9941           43757 Brown Lodge\nValerieberg, PR 88518  68 DG       AM
# 9948  95544 Johnson Isle Suite 939\nMichaelberg, RI ...  91 bW       AM
# 9954  051 Samantha Wells Apt. 328\nScottborough, OR ...  11 vG       AM
# 9981  087 Larson Roads Apt. 587\nRicestad, WI 98077-...  95 Kw       AM
# 9987     2754 Klein Mission\nJohnsonview, PA 64925-9624  65 Fg       PM
#
#                                            Browser Info  \
# ...

# %%
# 12. Find the email of the person with the following Credit Card Number: 4664825258997302
df[df['Credit Card']==4664825258997302][["Email"]]
# Out:
#                   Email
# 9992  bberry@wright.net

# %%
df[df['Credit Card']==4664825258997302][["Email"]].to_string(index=False)
# Out:
# '            Email\nbberry@wright.net'

# %%
# 13. How many people purchase during the AM and how many people purchase during PM?(value_counts())
df['AM or PM'].value_counts()
# Out:
# AM or PM
# PM    5068
# AM    4932
# Name: count, dtype: int64

# %%
# 14. How many people have a credit card that expires in 2020?
df.columns
# Out:
# Index(['Address', 'Lot', 'AM or PM', 'Browser Info', 'Company', 'Credit Card',
#        'CC Exp Date', 'CC Security Code', 'CC Provider', 'Email', 'Job',
#        'IP Address', 'Language', 'Purchase Price'],
#       dtype='object')

# %%
df['CC Exp Date']
# Out:
# 0       02/20
# 1       11/18
# 2       08/19
# 3       02/24
# 4       10/25
#         ...
# 9995    03/22
# 9996    07/25
# 9997    05/21
# 9998    11/17
# 9999    02/19
# Name: CC Exp Date, Length: 10000, dtype: object

# %%
df[df['CC Exp Date'].str.contains('/20')].shape[0]
# Out:
# 988

# %%
# 15. What are the top 5 most popular email providers (e.g. gmail.com, yahoo.com, etc...)
df['Email']
# Out:
# 0                    pdunlap@yahoo.com
# 1                   anthony41@reed.com
# 2       amymiller@morales-harrison.com
# 3          brent16@olson-robinson.info
# 4          christopherwright@gmail.com
#                      ...
# 9995            iscott@wade-garner.com
# 9996                mary85@hotmail.com
# 9997                 tyler16@gmail.com
# 9998           elizabethmoore@reid.net
# 9999             rachelford@vaughn.com
# Name: Email, Length: 10000, dtype: object

# %%
df['Email'].str.split('@').str[1].value_counts().head(5)
# Out:
# Email
# hotmail.com     1638
# yahoo.com       1616
# gmail.com       1605
# smith.com         42
# williams.com      37
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['Address', 'Lot', 'AM or PM', 'Browser Info', 'Company', 'Credit Card',
#        'CC Exp Date', 'CC Security Code', 'CC Provider', 'Email', 'Job',
#        'IP Address', 'Language', 'Purchase Price'],
#       dtype='object')

# %%
df[df.index%2==0]
# Out:
#                                                 Address    Lot AM or PM  \
# 0     16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 2                      Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 4     23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# 6        93971 Conway Causeway\nAndersonburgh, AZ 75107  96 Xt       AM
# 8               2129 Dylan Burg\nNew Michelle, ME 28650  45 JN       PM
# ...                                                 ...    ...      ...
# 9990  75731 Molly Springs\nWest Danielle, VT 96934-5102  93 ty       PM
# 9992  885 Allen Mountains Apt. 230\nWallhaven, LA 16995  40 vH       PM
# 9994       6276 Rojas Hollow\nLake Louis, WY 56410-7837  93 Ex       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
#
#                                            Browser Info  \
# ...

# %%
df.describe()
# Out:
#         Credit Card  CC Security Code  Purchase Price
# count  1.000000e+04      10000.000000    10000.000000
# mean   2.341374e+15        907.217800       50.347302
# std    2.256103e+15       1589.693035       29.015836
# min    6.040186e+10          0.000000        0.000000
# 25%    3.056322e+13        280.000000       25.150000
# 50%    8.699942e+14        548.000000       50.505000
# 75%    4.492298e+15        816.000000       75.770000
# max    6.012000e+15       9993.000000       99.990000

# %%
df.describe(include='object')
# Out:
#                                                   Address    Lot AM or PM  \
# count                                               10000  10000    10000
# unique                                              10000   9822        2
# top     16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  16 gc       PM
# freq                                                    1      2     5068
#
#                                              Browser Info    Company  \
# count                                               10000      10000
# unique                                               8287       8653
# top     Mozilla/5.0 (compatible; MSIE 9.0; Windows CE;...  Brown Ltd
# freq                                                   12         15
#
#        CC Exp Date   CC Provider               Email  \
# count        10000         10000               10000
# unique         121            10                9954
# top          08/22  JCB 16 digit  leekathy@yahoo.com
# ...

# %%
df.describe(include='all')
# Out:
#                                                   Address    Lot AM or PM  \
# count                                               10000  10000    10000
# unique                                              10000   9822        2
# top     16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  16 gc       PM
# freq                                                    1      2     5068
# mean                                                  NaN    NaN      NaN
# std                                                   NaN    NaN      NaN
# min                                                   NaN    NaN      NaN
# 25%                                                   NaN    NaN      NaN
# 50%                                                   NaN    NaN      NaN
# 75%                                                   NaN    NaN      NaN
# max                                                   NaN    NaN      NaN
#
#                                              Browser Info    Company  \
# ...
